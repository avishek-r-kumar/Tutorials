# %% [markdown]
# # Pandas Pivot Table
#
# Tutorial of Pivot Tables
# [Tutorial](http://pbpython.com/pandas-pivot-table-explained.html)

# %%
# %pylab inline 
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#!wget http://pbpython.com/extras/sales-funnel.xlsx

# %%
df = pd.read_excel('sales-funnel.xlsx')
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df['Status'] = df["Status"].astype("category")
df['Status'].cat.set_categories(["won","pending","presented",
                                 "declined"],inplace=True)

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pd.pivot_table(df,index=["Name","Rep","Manager"])
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# ...

# %%
pd.pivot_table(df,index=["Manager","Rep"],values=['Price'],
              aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
pd.pivot_table(df,index=["Manager","Rep"],values=["Price"],aggfunc=[np.mean,len])
# Out:
#                               mean   len
#                              Price Price
# Manager       Rep
# Debra Henley  Craig Booker   20000     4
#               Daniel Hilton  38333     3
#               John Smith     20000     2
# Fred Anderson Cedric Moss    27500     4
#               Wendy Yule     44250     4

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
df.set_index(["Manager","Rep"])
# Out:
#                              Account                          Name  \
# Manager       Rep
# Debra Henley  Craig Booker    714466               Trantow-Barrows
#               Craig Booker    714466               Trantow-Barrows
#               Craig Booker    714466               Trantow-Barrows
#               Craig Booker    737550  Fritsch, Russel and Anderson
#               Daniel Hilton   146832                  Kiehn-Spinka
#               Daniel Hilton   218895                     Kulas Inc
#               Daniel Hilton   218895                     Kulas Inc
#               John Smith      412290                 Jerde-Hilpert
#               John Smith      740150                    Barton LLC
# Fred Anderson Cedric Moss     141962                    Herman LLC
#               Cedric Moss     163416                   Purdy-Kunde
#               Cedric Moss     239344                    Stokes LLC
#               Cedric Moss     239344                    Stokes LLC
# ...

# %%
pd.pivot_table(df,index=["Manager","Rep"],values=["Price"],
               columns=["Product"],aggfunc=[np.sum])
# Out:
#                                 sum
#                               Price
# Product                         CPU Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker    65000        5000     NaN    10000
#               Daniel Hilton  105000         NaN     NaN    10000
#               John Smith      35000        5000     NaN      NaN
# Fred Anderson Cedric Moss     95000        5000     NaN    10000
#               Wendy Yule     165000        7000    5000      NaN

# %%
pd.pivot_table(df,index=["Manager","Rep","Product"],values=["Price",'Quantity'],
               aggfunc=[np.sum],fill_value=0,margins=True)
# Out:
#                                             sum
#                                           Price Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2
#                             Maintenance    5000        2
#                             Software      10000        1
#               Daniel Hilton CPU          105000        4
#                             Software      10000        1
#               John Smith    CPU           35000        1
#                             Maintenance    5000        2
# Fred Anderson Cedric Moss   CPU           95000        3
#                             Maintenance    5000        1
#                             Software      10000        1
#               Wendy Yule    CPU          165000        7
#                             Maintenance    7000        3
#                             Monitor        5000        2
# All                                      522000       30

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pd.pivot_table(df,index=['Manager','Status'],values=['Price'],fill_value=0,aggfunc=[np.sum],margins=True)
# Out:
#                             sum
#                           Price
# Manager       Status
# Debra Henley  won         65000
#               pending     50000
#               presented   50000
#               declined    70000
# Fred Anderson won        172000
#               pending      5000
#               presented   45000
#               declined    65000
# All                      522000

# %%
table = pd.pivot_table(df,index=["Manager","Status"],columns=["Product"],values=["Quantity","Price"],
               aggfunc={"Quantity":len,"Price":[np.sum,np.mean]},fill_value=0)
table
# Out:
#                          Price                                       \
#                           mean                                  sum
# Product                    CPU Maintenance Monitor Software     CPU
# Manager       Status
# Debra Henley  won        65000           0       0        0   65000
#               pending    40000        5000       0        0   40000
#               presented  30000           0       0    10000   30000
#               declined   35000           0       0        0   70000
# Fred Anderson won        82500        7000       0        0  165000
#               pending        0        5000       0        0       0
#               presented  30000           0    5000    10000   30000
#               declined   65000           0       0        0   65000
#
#                                                      Quantity              \
#                                                           len
# ...

# %%
table.query('Manager == ["Debra Henley"]')
# Out:
#                         Price                                                  \
#                          mean                                 sum
# Product                   CPU Maintenance Monitor Software    CPU Maintenance
# Manager      Status
# Debra Henley won        65000           0       0        0  65000           0
#              pending    40000        5000       0        0  40000       10000
#              presented  30000           0       0    10000  30000           0
#              declined   35000           0       0        0  70000           0
#
#                                         Quantity
#                                              len
# Product                Monitor Software      CPU Maintenance Monitor Software
# Manager      Status
# Debra Henley won             0        0        1           0       0        0
#              pending         0        0        1           2       0        0
# ...

# %%
table.query('Status == ["pending", "won"]')
# Out:
#                        Price                                                   \
#                         mean                                  sum
# Product                  CPU Maintenance Monitor Software     CPU Maintenance
# Manager       Status
# Debra Henley  won      65000           0       0        0   65000           0
#               pending  40000        5000       0        0   40000       10000
# Fred Anderson won      82500        7000       0        0  165000        7000
#               pending      0        5000       0        0       0        5000
#
#                                        Quantity
#                                             len
# Product               Monitor Software      CPU Maintenance Monitor Software
# Manager       Status
# Debra Henley  won           0        0        1           0       0        0
#               pending       0        0        1           2       0        0
# ...

# %%
df.query('Account==[714466]')
# Out:
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending

# %%
df[df['Account'] == 714466]
# Out:
#    Account             Name           Rep       Manager      Product  \
# 0   714466  Trantow-Barrows  Craig Booker  Debra Henley          CPU
# 1   714466  Trantow-Barrows  Craig Booker  Debra Henley     Software
# 2   714466  Trantow-Barrows  Craig Booker  Debra Henley  Maintenance
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 1         1  10000  presented
# 2         2   5000    pending

# %%
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
pd.pivot_table(df,index=['Manager','Rep','Status'],values=['Price','Quantity'],
               columns=["Product"],aggfunc={"Quantity":len,"Price":[np.sum,np.mean]},fill_value=0)
# Out:
#                                         Price                               \
#                                          mean
# Product                                   CPU Maintenance Monitor Software
# Manager       Rep           Status
# Debra Henley  Craig Booker  pending         0        5000       0        0
#                             presented   30000           0       0    10000
#                             declined    35000           0       0        0
#               Daniel Hilton won         65000           0       0        0
#                             pending     40000           0       0        0
#                             presented       0           0       0    10000
#               John Smith    pending         0        5000       0        0
#                             declined    35000           0       0        0
# Fred Anderson Cedric Moss   won         65000           0       0        0
# ...

# %%
table = pd.pivot_table(df,index=['Manager','Status'],values=['Price','Quantity'],
               columns=["Product"],aggfunc={"Quantity":len,"Price":[np.sum,np.mean]},fill_value=0)

# %%
table[table['Quantity']['len']['CPU'] > 1]
# Out:
#                         Price                                       \
#                          mean                                  sum
# Product                   CPU Maintenance Monitor Software     CPU
# Manager       Status
# Debra Henley  declined  35000           0       0        0   70000
# Fred Anderson won       82500        7000       0        0  165000
#
#                                                     Quantity              \
#                                                          len
# Product                Maintenance Monitor Software      CPU Maintenance
# Manager       Status
# Debra Henley  declined           0       0        0        2           0
# Fred Anderson won             7000       0        0        2           1
#
#
#
# Product                Monitor Software
# Manager       Status
# Debra Henley  declined       0        0
# Fred Anderson won            0        0
